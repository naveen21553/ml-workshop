# %% [markdown]
# # Matplotlib - pyplot

# %% [markdown]
# #### Import Library

# %%
import matplotlib.pyplot as plt

# %%
year = [1950, 1970, 1990, 2010]
pop = [2.159, 3.692, 5.263, 6.972]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x, y)

# %% [markdown]
# ### adding more data realistic data

# %%
import pandas as pd

# %%
df = pd.read_csv('world_pop.csv', skiprows = 1, usecols = [1, 2], names = ['year', 'pop'])

# %%
df.head()
# Out:
#    Year   Pop
# 0  1950  2.53
# 1  1951  2.57
# 2  1952  2.62
# 3  1953  2.67
# 4  1954  2.71

# %%
df.columns
# Out:
# Index(['year', 'pop'], dtype='object')

# %%
plt.plot(df['year'], df['pop'])

# %%
plt.scatter(df['year'], df['pop'])
plt.yscale()
