# %% [markdown]
# # Customizing the plots

# %% [markdown]
# There are many types of plots and many customizations
#
# Choice depends on-
#
# 1. The Data
# 2. The story you want to tell

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv('world_pop.csv', usecols = [1,2], skiprows = 1, names = ['year', 'pop'])

# %%
df.head()
# Out:
#    year   pop
# 0  1950  2.53
# 1  1951  2.57
# 2  1952  2.62
# 3  1953  2.67
# 4  1954  2.71

# %%
plt.plot(df['year'], df['pop'])

# %%
year = df['year']
pop = df['pop']

# %%
type(year)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Adding Title and X Y labels

# %%
plt.plot(year, pop)
plt.title('World Population Projection')

plt.xlabel('Year')
plt.ylabel('Population in Billions')
# Out:
# ([<matplotlib.axis.YTick at 0x2ae7ab277f0>,
#   <matplotlib.axis.YTick at 0x2ae7ab27668>,
#   <matplotlib.axis.YTick at 0x2ae7ab2c160>,
#   <matplotlib.axis.YTick at 0x2ae7ab4ea90>,
#   <matplotlib.axis.YTick at 0x2ae7ab55128>,
#   <matplotlib.axis.YTick at 0x2ae7ab55780>],
#  <a list of 6 Text yticklabel objects>)

# %% [markdown]
# ### Shifting y axis up to start values with 0

# %%
plt.plot(year, pop)
plt.title('World Population Projection')

plt.xlabel('Year')
plt.ylabel('Population in Billions')

plt.yticks([0, 2, 4, 6, 8, 10])
# Out:
# ([<matplotlib.axis.YTick at 0x2ae7ab834a8>,
#   <matplotlib.axis.YTick at 0x2ae7ab27828>,
#   <matplotlib.axis.YTick at 0x2ae7ab88160>,
#   <matplotlib.axis.YTick at 0x2ae7ababcc0>,
#   <matplotlib.axis.YTick at 0x2ae7abb5358>,
#   <matplotlib.axis.YTick at 0x2ae7abb59e8>],
#  <a list of 6 Text yticklabel objects>)

# %% [markdown]
# ### Adding meaningful tickers for y axis

# %%
plt.plot(year, pop)
plt.title('World Population Projection')

plt.xlabel('Year')
plt.ylabel('Population in Billions')

plt.yticks([0, 2, 4, 6, 8, 10], ['0 B', '2 B', '4 B', '6 B', '8 B', '10 B'])
# Out:
# ([<matplotlib.axis.YTick at 0x2ae7abe90f0>,
#   <matplotlib.axis.YTick at 0x2ae7abe9390>,
#   <matplotlib.axis.YTick at 0x2ae7abe9dd8>,
#   <matplotlib.axis.YTick at 0x2ae7ac0deb8>,
#   <matplotlib.axis.YTick at 0x2ae7ac15550>,
#   <matplotlib.axis.YTick at 0x2ae7ac15ba8>],
#  <a list of 6 Text yticklabel objects>)

# %%
year = [1800, 1850, 1900] + list(year)
pop = [1.0, 1.262, 1.650] + list(pop)

# %%
plt.plot(year, pop)
plt.title('World Population Projection')

plt.xlabel('Year')
plt.ylabel('Population in Billions')

plt.yticks([0, 2, 4, 6, 8, 10], ['0 B', '2 B', '4 B', '6 B', '8 B', '10 B'])
# Out:
# ([<matplotlib.axis.YTick at 0x2ae7accacc0>,
#   <matplotlib.axis.YTick at 0x2ae7accaac8>,
#   <matplotlib.axis.YTick at 0x2ae7acd4e48>,
#   <matplotlib.axis.YTick at 0x2ae7acff7f0>,
#   <matplotlib.axis.YTick at 0x2ae7acffe48>,
#   <matplotlib.axis.YTick at 0x2ae7ad054e0>],
#  <a list of 6 Text yticklabel objects>)
